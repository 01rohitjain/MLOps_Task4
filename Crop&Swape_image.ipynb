# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img1=cv2.imread("dog.jpg")

# %%
cv2.imshow("img",img1)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
img2=cv2.imread("Cat.jpg")

# %%
cv2.imshow("img2",img2)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
img1=cv2.imread("dog.jpg")
img2=cv2.imread("Cat.jpg")
img1 =cv2.resize(img1,(450,300))
img2=cv2.resize(img2,(450,300))

# %%
plt.imshow(img1)

# %%
img3=img1[45:260,50:360]

# %%
cv2.imshow("dog",img3)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
plt.imshow(img2)

# %%
img4=img2[0:250,50:360]

# %%
cv2.imshow("cat",img4)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
img3=cv2.resize(img3,(310,250))
img4=cv2.resize(img4,(310,215))

# %%
img2[0:250,50:360]= img3
img1[45:260,50:360]=img4

# %%
plt.imshow(img2)

# %%
plt.imshow(img1)
